# %%
import pandas as pd

csv_provided = pd.read_csv('x_ca_omcc_providers.csv', names=["provider_name", "type_of_care", "address", "city", "state", "zip", "phone"])
api_data = pd.read_csv('outputs/api_data.csv')
scraped_data = pd.read_csv('outputs/scraped_data.csv')

# Would prefer to do this in SQL (matching phone format to other sources)

clean_nums = []
for phone_no in csv_provided['phone']:
    contactphone = "(%c%c%c) %c%c%c-%c%c%c%c" % tuple(map(ord,list(str(phone_no)[:10])))    
    clean_nums.append(contactphone)

csv_provided['phone'] = clean_nums


#  With more time, I'd wrap this in a function and print out differences

csv_provided = csv_provided.drop_duplicates()   # 51 dupes removed
scraped_data = scraped_data.drop_duplicates()  # No dupes removed
api_data = api_data.drop_duplicates() # No dupes removed

# %%
api_data
# Out:
#       Unnamed: 0                               id  \
# 0              0  prvdrs_xTVZPYTrIzsRBVJojkuHkRh6
# 1              1  prvdrs_9XYNilFfFjGeJjWbjP2uvLje
# 2              2  prvdrs_6fwq7dwGBVctHrZWbpBuZhWJ
# 3              3  prvdrs_8YF3tyi0eeqlJm1UIeOZVx68
# 4              4  prvdrs_nH2OzYh77wA1vs2aXsMqfNLx
# ...          ...                              ...
# 1495        1495  prvdrs_6NfAOQ6bTQPv56fNskH0RSfF
# 1496        1496  prvdrs_KDnJgmvmAbwY13BUTZQYf6vY
# 1497        1497  prvdrs_pDZIfFWzSKI97EvHotqqw1LR
# 1498        1498  prvdrs_akzHqvph9OyodWo6q7FxLBFB
# 1499        1499  prvdrs_56127MTi8TyyPofYDfOqBDw2
#
#                                provider_name           phone  \
# 0       La Rue Park Child Development Center  (530) 753-8716
# 1                         Carousel Preschool  (310) 216-6641
# 2                Adventure Club - Quail Glen  (916) 772-7529
# 3              Adventure Club - Coyote Ridge  (916) 772-7271
# 4                     Azusa Discovery Center  (626) 334-1806
# ...                                      ...             ...
# 1495               KCE Champions LLC @ Mason  (503) 872-1464
# 1496                           Amy Lee Ulloa  (805) 264-8234
# 1497               Chapman Montessori School  (714) 591-5927
# 1498  Kid Ventures Liberty Station Preschool  (619) 573-9625
# 1499                   Ocean View Pre-School  (310) 514-1048
#
#                             email        owner_name
# 0             snfaria@ucdavis.edu    Elizabeth Wall
# 1      jane.uy@carouselschool.com  Shaneka Kittrell
# 2       jrutledge@roseville.ca.us   Dewayne Bunning
# 3       vsisneroz@roseville.ca.us  Ernest Edmondson
# 4             jhdmaddox60@msn.com     William Bliss
# ...                           ...               ...
# 1495     subsidy@kc-education.com      Allen Harder
# 1496          orcuttlee@yahoo.com       Jason Moons
# 1497  chapmanmontessori@gmail.com         Ana Drake
# 1498  christena@sdkidventures.com       Jill Stokes
# 1499      preschool@oceanview.org   Melia Rodriguez
#
# [1500 rows x 6 columns]
